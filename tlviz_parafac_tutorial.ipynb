# %%
# %load_ext autoreload
# %autoreload 2

import tlviz
import matplotlib.pyplot as plt
import tensorly as tl
from tensorly.decomposition import parafac, parafac2

tl.set_backend("pytorch")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
aminoacids = tlviz.data.load_aminoacids()
# Out:
# Loading Aminoacids dataset from:
# Bro, R, PARAFAC: Tutorial and applications, Chemometrics and Intelligent Laboratory Systems, 1997, 38, 149-171

# %%
aminoacids
# Out:
# <xarray.DataArray (Sample: 5, Excitation frequency: 61, Emission frequency: 201)> Size: 490kB
# [61305 values with dtype=float64]
# Coordinates:
#   * Emission frequency    (Emission frequency) float64 2kB 250.0 251.0 ... 450.0
#   * Excitation frequency  (Excitation frequency) float64 488B 240.0 ... 300.0
#   * Sample                (Sample) int32 20B 0 1 2 3 4

# %%
X = tl.tensor(aminoacids.data)
cp_tensor_1 = parafac(X, 3, init="random", random_state=0)
cp_tensor_2 = parafac2(X, 3, init="random", random_state=0)

# %%
cp_tensor_1
# Out:
# (weights, factors) : rank-3 CPTensor of shape (5, 61, 201)

# %%
cp_tensor_2
=
# Out:
# (weights, factors, projections) : rank-3 Parafac2Tensor of shape ((61, 201), (61, 201), (61, 201), (61, 201), (61, 201))

# %%
fig, ax = tlviz.visualisation.components_plot(cp_tensor)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/jonathan/mres_thesis/pca_analysis/tlviz_parafac_tutorial.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/jonathan/mres_thesis/pca_analysis/tlviz_parafac_tutorial.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> fig, ax = tlviz.visualisation.components_plot(cp_tensor)
#       <a href='vscode-notebook-cell:/Users/jonathan/mres_thesis/pca_analysis/tlviz_parafac_tutorial.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> plt.show()
#
# File ~/Library/Caches/pypoetry/virtualenvs/pca-analysis-6KQS4gUX-py3.12/lib/python3.12/site-packages/tlviz/_tl_utils.py:104, in _handle_tensorly_backends_cp.<locals>.decorator.<locals>.func2(*args, **kwargs)
#     102     raise ValueError("cp_tensor is None, but it is not optional.")
#     103 else:
# --> 104     np_cp_tensor = to_numpy_cp(cp_tensor, cast_labelled_cp=False)
#     106 bound_arguments.arguments[cp_tensor_name] = np_cp_tensor
#     107 out = func(*bound_arguments.args, **bound_arguments.kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/pca-analysis-6KQS4gUX-py3.12/lib/python3.12/site-packages/tlviz/_tl_utils.py:63, in to_numpy_cp(cp_tensor, cast_labelled_cp)
#      60     weights, factors = cp_tensor
#      61     return weights, [factor.values for factor in factors]
# ---> 63 if not is_tensorly_cp(cp_tensor):
#      64     return cp_tensor
#      66 weights, factors = cp_tensor
#
# File ~/Library/Caches/pypoetry/virtualenvs/pca-analysis-6KQS4gUX-py3.12/lib/python3.12/site-packages/tlviz/_tl_utils.py:34, in is_tensorly_cp(cp_tensor, none_ok)
#      31 if not HAS_TENSORLY:
#      32     return False
# ---> 34 weights, factors = cp_tensor
#      35 tl_weights = tl.is_tensor(weights) or weights is None
#      36 tl_factors = [tl.is_tensor(factor) for factor in factors]
#
# ValueError: too many values to unpack (expected 2)

# %%
cp_tensor_postprocessed = tlviz.postprocessing.postprocess(cp_tensor, aminoacids)
fig, ax = tlviz.visualisation.components_plot(cp_tensor_postprocessed)
plt.show()
